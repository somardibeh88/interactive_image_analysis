# %%
from data_loader import DataLoader, EELSLazyLoader

# %%
from data_loader import DataLoader, EELSLazyLoader
filepath_ndata = '/home/somar/Desktop/own_stuff/cleaning script/example data files/081.ndata1'
filepath_tiff = '/home/somar/Desktop/own_stuff/cleaning script/example data files/VCR stack (MAADF) cluster_2 14.11.tif'
filepath_pkl = '/home/somar/Desktop/own_stuff/cleaning script/example data files/stack.pkl'
metadata_pkl = '/home/somar/Desktop/own_stuff/cleaning script/example data files/metadata.pkl'
filepath_h5 = '/home/somar/Desktop/own_stuff/cleaning script/example data files/stack.h5'
filepath_eels = '/home/somar/Desktop/own_stuff/cleaning script/example data files/eels_point_spectrum_pairs.h5'
stacks_ssb = ['/home/somar/Desktop/2025/Data for publication/Sample 2525/SSB reconstruction of 4d STEM data/stack_ssbs.h5']
img = DataLoader(stacks_ssb[0])
data = img.raw_data
metadata = img.raw_metadata
print(f"Number of images: {len(data)}")
print(metadata[0])
fov = img.get_specific_metadata('timezone', data = metadata['metadata_0022'])
fov
# Out:
# Number of images: 83
# {'version': 1, 'reader_version': 1, 'large_format': False, 'spatial_calibrations': [{'offset': -4.0, 'scale': 0.015625, 'units': 'nm'}, {'offset': -4.0, 'scale': 0.015625, 'units': 'nm'}], 'intensity_calibration': {'offset': 0.0, 'scale': 1.0, 'units': 'counts'}, 'collection_dimension_count': 0, 'datum_dimension_count': 2, 'metadata': {}, 'properties': {}, 'title': 'SSB (AC) 10', 'source_file_path': None, 'datetime_modified': {'local_datetime': '2025-04-10T08:37:13.907129', 'tz': '+0200', 'dst': '+60', 'timezone': 'Europe/Vienna'}, 'datetime_original': {'local_datetime': '2025-04-10T08:37:13.907129', 'tz': '+0200', 'dst': '+60', 'timezone': 'Europe/Vienna'}, 'uuid': '04982611-0b3c-4a7f-b873-fcc117e72cbd'}
# ['Europe/Vienna', 'Europe/Vienna']

# %%
# Load Ndata1 VCR stacks
fp1 = '/home/somar/Desktop/2025/Data for publication/ADF sequences_20-01-2025/stack.h5'
fp2 = '/home/somar/Desktop/2025/Data for publication/ADF sequences_20-01-2025/Sequence-HAADF-2_2025-01-20T221437.166476_100x512x512_2.ndata1'
from data_loader import DataLoader, EELSLazyLoader
img = DataLoader(fp2)

data = img.raw_data
metadata = img.raw_metadata
print(data.shape)
print(metadata[0])
fov = img.get_specific_metadata(target_key='fov_nm', required_keys=["scan_device_properties"])
print(f"Field of view: {fov}")
# Out:
# (100, 512, 512)
# {'version': 1, 'reader_version': 1, 'large_format': False, 'spatial_calibrations': [{'offset': 0.0, 'scale': 1.0, 'units': ''}, {'offset': -8.0, 'scale': 0.03125, 'units': 'nm'}, {'offset': -8.0, 'scale': 0.03125, 'units': 'nm'}], 'intensity_calibration': {'offset': 0.0, 'scale': 1.0, 'units': ''}, 'is_sequence': True, 'collection_dimension_count': 0, 'datum_dimension_count': 2, 'metadata': {'instrument': {'high_tension': 60000.0, 'defocus': 3.90763345174762e-09, 'ImageScanned': {'C1 ConstW': 0.563546000000003, 'EHT': 60000.0, 'PMTBF_gain': 6400.0, 'PMTDF_gain': 80000.0, 'S_EELS': 1.0, 'StageOutA': -1.17060138569237e-08, 'StageOutB': 1.03801286139456e-08, 'StageOutX': -0.000899376610199899, 'StageOutY': 0.00029473417242559, 'StageOutZ': 0.000408499320253794, 'BP2_^VGVOACurrent': 6.031116e-10, 'probe_ha': 0.035, 'C10': 3.90763345174762e-09, 'C12.a': -2.12493303751028e-09, 'C12.b': 1.56075592419706e-09, 'C21.a': 1.40292938644959e-07, 'C21.b': -9.40980715101662e-08, 'C23.a': -1.14033809595013e-08, 'C23.b': 5.35515961075453e-08, 'C30': -4.65286050362568e-06, 'C32.a': 7.16327419558534e-06, 'C32.b': -4.96239462129809e-06, 'C34.a': -1.97623000273698e-08, 'C34.b': 4.86058915385265e-07, 'C41.a': -0.000179665994826146, 'C41.b': 0.000120506589942353, 'C43.a': 2.19055905905777e-05, 'C43.b': -0.000102871187410997, 'C45.a': -3.51654942645782e-05, 'C45.b': -1.53210324117638e-05, 'C50': -0.000653935892940758, 'C52.a': -0.00335627278050581, 'C52.b': 0.00194452974383046, 'C54.a': -0.00116205198674251, 'C54.b': -9.37873861637805e-05, 'C56.a': -9.85071513168029e-05, 'C56.b': 0.000145232826503806}}, 'scan': {'hardware_source_id': 'superscan', 'hardware_source_name': 'SuperScan', 'scan_id': '0c8441b5-5c2a-4fba-9e65-460f47c83896', 'center_x_nm': 0.0, 'center_y_nm': 0.0, 'fov_nm': 16.0, 'rotation': 0.0, 'rotation_deg': 0.0, 'scan_context_size': [512, 512], 'scan_size': [512, 512], 'scan_device_parameters': {'pixel_size': [512, 512], 'center_nm': [0.0, 0.0], 'pixel_time_us': 12.0, 'fov_nm': 16.0, 'rotation_rad': 0.0, 'ac_line_sync': False, 'ac_frame_sync': False, 'external_clock_mode': 0, 'external_clock_wait_time_ms': 0, 'external_scan_mode': 0, 'external_scan_ratio': 0.0, 'subscan_rotation': 0.0}, 'scan_device_properties': {'ImageScanned:ARINAPixelAngle': 0.0, 'ImageScanned:BP2_^VGVOACurrent': 6.03112e-10, 'ImageScanned:C1 ConstW': 0.563546, 'ImageScanned:C10': 3.90763e-09, 'ImageScanned:C12.a': -2.12493e-09, 'ImageScanned:C12.b': 1.56076e-09, 'ImageScanned:C21.a': 1.40293e-07, 'ImageScanned:C21.b': -9.40981e-08, 'ImageScanned:C23.a': -1.14034e-08, 'ImageScanned:C23.b': 5.35516e-08, 'ImageScanned:C30': -4.65286e-06, 'ImageScanned:C32.a': 7.16327e-06, 'ImageScanned:C32.b': -4.96239e-06, 'ImageScanned:C34.a': -1.97623e-08, 'ImageScanned:C34.b': 4.86059e-07, 'ImageScanned:C41.a': -0.000179666, 'ImageScanned:C41.b': 0.000120507, 'ImageScanned:C43.a': 2.19056e-05, 'ImageScanned:C43.b': -0.000102871, 'ImageScanned:C45.a': -3.51655e-05, 'ImageScanned:C45.b': -1.5321e-05, 'ImageScanned:C50': -0.000653936, 'ImageScanned:C52.a': -0.00335627, 'ImageScanned:C52.b': 0.00194453, 'ImageScanned:C54.a': -0.00116205, 'ImageScanned:C54.b': -9.37874e-05, 'ImageScanned:C56.a': -9.85072e-05, 'ImageScanned:C56.b': 0.000145233, 'ImageScanned:EHT': 60000.0, 'ImageScanned:PMTBF_gain': 6400.0, 'ImageScanned:PMTDF_gain': 80000.0, 'ImageScanned:S_EELS': 1.0, 'ImageScanned:StageOutA': -1.1706e-08, 'ImageScanned:StageOutB': 1.03801e-08, 'ImageScanned:StageOutX': -0.000899377, 'ImageScanned:StageOutY': 0.000294734, 'ImageScanned:StageOutZ': 0.000408499, 'ImageScanned:VacuumController.^OG': 1.3e-09, 'ImageScanned:probe_ha': 0.035, 'MagBoard 0 DAC 0': 0.0, 'MagBoard 0 DAC 1': 0.0, 'MagBoard 0 DAC 10': 9074.0, 'MagBoard 0 DAC 11': 6596.0, 'MagBoard 0 DAC 2': 0.0, 'MagBoard 0 DAC 3': 0.0, 'MagBoard 0 DAC 4': 9631.0, 'MagBoard 0 DAC 5': 59152.0, 'MagBoard 0 DAC 6': 10564.0, 'MagBoard 0 DAC 7': 59964.0, 'MagBoard 0 DAC 8': 54756.0, 'MagBoard 0 DAC 9': 60482.0, 'MagBoard 0 Relay': 32.0,  ...
# Field of view: [15.9999995474891]

# %%
# %matplotlib qt5
# from vcr_to_gif_calibrated import VCRToGIF
# font_path = "/home/somar/.fonts/SourceSansPro-Semibold.otf" 

# vcr_to_gif = VCRToGIF(fp2)
# vcr_to_gif.images.shape

# %%
# Reading pkl data example
idx = 10            # The image index you want to access and its metadata
data = DataLoader(filepath_pkl).raw_data
metadata = DataLoader(metadata_pkl).raw_metadata

print(type(metadata), type(metadata[0]))
print(f"Number of images: {len(data)}")
print(data[idx].shape)
print(f"Metadata: {metadata[idx]}")

fov= metadata.get_metadata(target_key='fov_nm', data = metadata[0][idx])

print(f"FOV: {fov}")

fov_specific = metadata.get_specific_metadata('fov_nm', required_keys=['scan_device_properties'], data = metadata[0][idx])
print(f"FOV specific: {fov_specific}")
# Out:
# <class 'data_loader.UnifiedLoader._load_pkl.<locals>.PklMetadataLoader'> <class 'list'>
# Number of images: 11
# (2048, 2048)
# Metadata: [{'version': 1, 'reader_version': 1, 'large_format': False, 'spatial_calibrations': [{'offset': -16.0, 'scale': 0.03125, 'units': 'nm'}, {'offset': -16.0, 'scale': 0.03125, 'units': 'nm'}], 'intensity_calibration': {'offset': 0.0, 'scale': 1.0, 'units': ''}, 'collection_dimension_count': 0, 'datum_dimension_count': 2, 'metadata': {'instrument': {'high_tension': 60000.0, 'defocus': -1.53695177923778e-08, 'ImageScanned': {'C1 ConstW': 0.563546000000003, 'EHT': 60000.0, 'PMTBF_gain': 6400.0, 'PMTDF_gain': 10000.0, 'S_EELS': 8.0, 'StageOutA': -8.19420969984657e-08, 'StageOutB': -3.11403858418367e-08, 'StageOutX': -0.000147694296095732, 'StageOutY': 8.26452710620804e-05, 'StageOutZ': 0.00044554713865899, 'BP2_^VGVOACurrent': 6.031116e-10, 'probe_ha': 0.035, 'C10': -1.53695177923778e-08, 'C12.a': -1.00717664423343e-09, 'C12.b': 4.69170607684303e-10, 'C21.a': 1.40292938644959e-07, 'C21.b': -9.40980715101662e-08, 'C23.a': -1.14033809595013e-08, 'C23.b': 5.35515961075453e-08, 'C30': -5.98589075166172e-06, 'C32.a': 4.41488352591077e-06, 'C32.b': -2.27835459513263e-06, 'C34.a': -6.77826567680572e-08, 'C34.b': -9.74326478964702e-07, 'C41.a': -0.000179665994826146, 'C41.b': 0.000120506589942353, 'C43.a': 2.19055905905777e-05, 'C43.b': -0.000102871187410997, 'C45.a': -3.51654942645782e-05, 'C45.b': -1.53210324117638e-05, 'C50': -0.000653935892940758, 'C52.a': -0.00335627278050581, 'C52.b': 0.00194452974383046, 'C54.a': -0.00116205198674251, 'C54.b': -9.37873861637805e-05, 'C56.a': -9.85071513168029e-05, 'C56.b': 0.000145232826503806}}, 'scan': {'hardware_source_id': 'superscan', 'hardware_source_name': 'SuperScan', 'scan_id': 'f54d5478-39d9-4804-a889-fe201cecc3b0', 'center_x_nm': 0.0, 'center_y_nm': 0.0, 'fov_nm': 32.0, 'rotation': 0.0, 'rotation_deg': 0.0, 'scan_context_size': [1024, 1024], 'scan_size': [1024, 1024], 'scan_device_parameters': {'pixel_size': [1024, 1024], 'center_nm': [0.0, 0.0], 'pixel_time_us': 16.0, 'fov_nm': 32.0, 'rotation_rad': 0.0, 'ac_line_sync': False, 'ac_frame_sync': False, 'external_clock_mode': 0, 'external_clock_wait_time_ms': 0, 'external_scan_mode': 0, 'external_scan_ratio': 0.0}, 'scan_device_properties': {'ac_line_sync': 2.0, 'calibration_style': 'space', 'center_x_nm': 0.0, 'center_y_nm': 0.0, 'flyback_pixels': 14.0, 'flyback_time_us': 224.0, 'fov_nm': 31.9999990949782, 'line_time_us': 16608.0, 'pixel_time_us': 16.0, 'pixels_x': 1024.0, 'pixels_y': 1024.0, 'requested_pixel_time_us': 15.9999999596039, 'rotation_deg': 0.0, 'rotation_rad': 0.0, 'mag_boards': {'MagBoard 0 DAC 0': 0.0, 'MagBoard 0 DAC 1': 0.0, 'MagBoard 0 DAC 10': 4587.0, 'MagBoard 0 DAC 11': 3335.0, 'MagBoard 0 DAC 2': 0.0, 'MagBoard 0 DAC 3': 0.0, 'MagBoard 0 DAC 4': 4869.0, 'MagBoard 0 DAC 5': 62309.0, 'MagBoard 0 DAC 6': 5341.0, 'MagBoard 0 DAC 7': 62719.0, 'MagBoard 0 DAC 8': 60086.0, 'MagBoard 0 DAC 9': 62981.0, 'MagBoard 0 Relay': 352.0, 'MagBoard 1 DAC 0': 0.0, 'MagBoard 1 DAC 1': 0.0, 'MagBoard 1 DAC 10': 56521.0, 'MagBoard 1 DAC 11': 4956.0, 'MagBoard 1 DAC 2': 0.0, 'MagBoard 1 DAC 3': 0.0, 'MagBoard 1 DAC 4': 57525.0, 'MagBoard 1 DAC 5': 4171.0, 'MagBoard 1 DAC 6': 7792.0, 'MagBoard 1 DAC 7': 60418.0, 'MagBoard 1 DAC 8': 58572.0, 'MagBoard 1 DAC 9': 4572.0, 'MagBoard 1 Relay': 352.0}}, 'valid_rows': 1024}, 'hardware_source': {'hardware_source_id': 'superscan', 'hardware_source_name': 'SuperScan', 'exposure': 16.777216, 'frame_index': 0, 'channel_id': 'b', 'channel_name': 'MAADF', 'pixel_time_us': 16.0, 'line_time_us': 16608.0, 'valid_rows': 1024, 'channel_index': 1, 'reference_key': 'superscan_b', 'view_id': 'c424a053-27eb-4771-8fc7-66f44bff1a96'}}, 'properties': {'hardware_source_id': 'superscan', 'hardware_source_name': 'SuperScan', 'exposure': 16.777216, 'frame_index': 0, 'channel_id': 'b', 'channel_name': 'MAADF', 'pixel_time_us': 16.0, 'line_time_us': 16608.0, 'valid_rows': 1024, 'channel_index': 1, 'reference_key': 'superscan_b', 'view_id': 'c424a053-27eb-4771-8fc7-66f44bff1a96'}, 'title': 'SuperScan (MAADF) 2', 'sou ...
# FOV: [128.0, 128.0, 127.999996379913]
# FOV specific: [127.999996379913]

# %%
# Reading Tiff data exmple
h5_file = '/home/somar/Desktop/2025/Data for publication/Sample 2344/ADF images/stack.h5'
img = DataLoader(filepath_h5)
data = img.raw_data
metadata = img.raw_metadata

print(f"Number of images: {len(data)}")
print(f"Metadata for first image: {metadata[0]}")
# Out:
# Number of images: 83
# Metadata for first image: {'version': 1, 'reader_version': 1, 'large_format': False, 'spatial_calibrations': [{'offset': -4.0, 'scale': 0.015625, 'units': 'nm'}, {'offset': -4.0, 'scale': 0.015625, 'units': 'nm'}], 'intensity_calibration': {'offset': 0.0, 'scale': 1.0, 'units': 'counts'}, 'collection_dimension_count': 0, 'datum_dimension_count': 2, 'metadata': {}, 'properties': {}, 'title': 'SSB (AC) 10', 'source_file_path': None, 'datetime_modified': {'local_datetime': '2025-04-10T08:37:13.907129', 'tz': '+0200', 'dst': '+60', 'timezone': 'Europe/Vienna'}, 'datetime_original': {'local_datetime': '2025-04-10T08:37:13.907129', 'tz': '+0200', 'dst': '+60', 'timezone': 'Europe/Vienna'}, 'uuid': '04982611-0b3c-4a7f-b873-fcc117e72cbd'}

# %%
# Reading NDATA data example
fp = '/home/somar/Desktop/own_stuff/cleaning script/example data files/SuperScan-MAADF_2025-02-26T153932.717062_2048x2048_0.ndata1'
fp2 = '/home/somar/Desktop/own_stuff/cleaning script/example data files/VCR stack (MAADF) cluster_2 14.11.ndata1'
img = DataLoader(fp)
data = img.raw_data
metadata = img.raw_metadata

print(f"Number of images: {len(data)}")
i = 0
print(data[i].shape, data[i])
print(f"Metadata: {metadata[0]}")
# Out:
# Number of images: 1
# (2048, 2048) [[0.00415039 0.00482178 0.00575765 ... 0.01704915 0.01619466 0.01934814]
#  [0.00441488 0.00626628 0.00508626 ... 0.01916504 0.0098877  0.01782227]
#  [0.00628662 0.00701904 0.00634766 ... 0.01477051 0.01224772 0.01660156]
#  ...
#  [0.01940918 0.01371257 0.01245117 ... 0.02288818 0.02886963 0.02490234]
#  [0.02152506 0.01332601 0.01033529 ... 0.0244751  0.02976481 0.03397624]
#  [0.01983643 0.0096639  0.0100708  ... 0.02174886 0.02258301 0.03155518]]
# Metadata: {'version': 1, 'reader_version': 1, 'large_format': False, 'spatial_calibrations': [{'offset': -256.0, 'scale': 0.25, 'units': 'nm'}, {'offset': -256.0, 'scale': 0.25, 'units': 'nm'}], 'intensity_calibration': {'offset': 0.0, 'scale': 1.0, 'units': ''}, 'collection_dimension_count': 0, 'datum_dimension_count': 2, 'metadata': {'instrument': {'high_tension': 60000.0, 'defocus': -5.36951779237778e-09, 'ImageScanned': {'C1 ConstW': 0.563546000000003, 'EHT': 60000.0, 'PMTBF_gain': 6400.0, 'PMTDF_gain': 10000.0, 'S_EELS': 8.0, 'StageOutA': -8.19420969984657e-08, 'StageOutB': -3.11403858418367e-08, 'StageOutX': -0.000147695123082913, 'StageOutY': 8.31850259302812e-05, 'StageOutZ': 0.00044553968265899, 'BP2_^VGVOACurrent': 6.031116e-10, 'probe_ha': 0.035, 'C10': -5.36951779237778e-09, 'C12.a': -1.00717664423343e-09, 'C12.b': 4.69170607684303e-10, 'C21.a': 1.40292938644959e-07, 'C21.b': -9.40980715101662e-08, 'C23.a': -1.14033809595013e-08, 'C23.b': 5.35515961075453e-08, 'C30': -5.98589075166172e-06, 'C32.a': 4.41488352591077e-06, 'C32.b': -2.27835459513263e-06, 'C34.a': -6.77826567680572e-08, 'C34.b': -9.74326478964702e-07, 'C41.a': -0.000179665994826146, 'C41.b': 0.000120506589942353, 'C43.a': 2.19055905905777e-05, 'C43.b': -0.000102871187410997, 'C45.a': -3.51654942645782e-05, 'C45.b': -1.53210324117638e-05, 'C50': -0.000653935892940758, 'C52.a': -0.00335627278050581, 'C52.b': 0.00194452974383046, 'C54.a': -0.00116205198674251, 'C54.b': -9.37873861637805e-05, 'C56.a': -9.85071513168029e-05, 'C56.b': 0.000145232826503806}}, 'scan': {'hardware_source_id': 'superscan', 'hardware_source_name': 'SuperScan', 'scan_id': '9b4d07da-d76f-41d3-abe3-b5f6b2141ff3', 'center_x_nm': 0.0, 'center_y_nm': 0.0, 'fov_nm': 128.0, 'rotation': 0.0, 'rotation_deg': 0.0, 'scan_context_size': [512, 512], 'scan_size': [512, 512], 'scan_device_parameters': {'pixel_size': [512, 512], 'center_nm': [0.0, 0.0], 'pixel_time_us': 8.0, 'fov_nm': 128.0, 'rotation_rad': 0.0, 'ac_line_sync': False, 'ac_frame_sync': False, 'external_clock_mode': 0, 'external_clock_wait_time_ms': 0, 'external_scan_mode': 0, 'external_scan_ratio': 0.0, 'subscan_rotation': 0.0}, 'scan_device_properties': {'ac_line_sync': 2.0, 'calibration_style': 'space', 'center_x_nm': 0.0, 'center_y_nm': 0.0, 'flyback_pixels': 14.0, 'flyback_time_us': 224.0, 'fov_nm': 127.999996379913, 'line_time_us': 4320.0, 'pixel_time_us': 8.0, 'pixels_x': 2048.0, 'pixels_y': 2048.0, 'requested_pixel_time_us': 15.9999999596039, 'rotation_deg': 0.0, 'rotation_rad': 0.0, 'mag_boards': {'MagBoard 0 DAC 0': 0.0, 'MagBoard 0 DAC 1': 0.0, 'MagBoard 0 DAC 10': 2576.0, 'MagBoard 0 DAC 11': 1872.0, 'MagBoard 0 DAC 2': 0.0, 'MagBoard 0 DAC 3': 0.0, 'MagBoard 0 DAC 4': 2734.0, 'MagBoard 0 DAC 5': 63724.0, 'MagBoard 0 DAC 6': 2999.0, 'MagBoard 0 DAC 7': 63954.0, 'MagBoard 0 DAC 8': 62476.0, 'MagBoard 0 DAC 9': 64101.0, 'MagBoard 0 Relay': 336.0, 'MagBoard 1 DAC 0': 0.0, 'MagBoard 1 DAC 1': 0.0, 'MagBoard 1 DAC 10': 60474.0, 'MagBoard 1 DAC 11': 2783.0, 'MagBoard 1 DAC 2': 0.0, 'MagBoard 1 DAC 3': 0.0, 'MagBoard 1 DAC 4': 61038.0, 'MagBoard 1 DAC 5': 2342.0, 'MagBoard 1 DAC 6': 4375.0, 'MagBoard 1 DAC 7': 62662.0, 'MagBoard 1 DAC 8': 61625.0, 'MagBoard 1 DAC 9': 2567.0, 'MagBoard 1 Relay': 336.0}}, 'valid_rows': 2048}, 'hardware_source': {'hardware_source_id': 'superscan', 'hardware_source_name': 'SuperScan', 'exposure': 33.554432, 'frame_index': 213, 'channel_id': 'b', 'channel_name': 'MAADF', 'pixel_time_us': 8.0, 'line_time_us': 4320.0, 'valid_rows': 2048, 'channel_index': 1, 'reference_key': 'superscan_b'}}, 'properties': {'hardware_source_id': 'superscan', 'hardware_source_name': 'SuperScan', 'exposure': 33.554432, 'frame_index': 213, 'channel_id': 'b', 'channel_name': 'MAADF', 'pixel_time_us': 8.0, 'line_time_us': 4320.0, 'valid_rows': 2048, 'channel_index': 1, 'reference_key': 'superscan_b'}, 'title': 'SuperScan (MAADF)', 'source_file_path': None, 'datetime_modified': {'local_datetime': '2025-02-26T15:39:32.717062', ...

# %%
# Reading HDF5 data example. For h5 file format I choosed to index the metadata following this system: metadata_0001, metadata_0002, etc. but you still can access them using normal indexing as shwon below.
img = DataLoader(filepath_h5)
data = img.raw_data
metadata = img.raw_metadata

print(f"Number of images: {len(data)}")
print(f"Metadata for first image: {metadata[0]}")

# get specific data and metadata at specific index
idx = 22
print(f"Image shape at index {idx}: {data[idx].shape}")

print(f"Metadata at index {idx}: {metadata[idx]}")
title = metadata.get_metadata('title', data=metadata[idx])
print(f"Image title at index {idx}: {title}")
print(metadata['metadata_0022'])
# Out:
# Number of images: 83
# Metadata for first image: {'version': 1, 'reader_version': 1, 'large_format': False, 'spatial_calibrations': [{'offset': -4.0, 'scale': 0.015625, 'units': 'nm'}, {'offset': -4.0, 'scale': 0.015625, 'units': 'nm'}], 'intensity_calibration': {'offset': 0.0, 'scale': 1.0, 'units': 'counts'}, 'collection_dimension_count': 0, 'datum_dimension_count': 2, 'metadata': {}, 'properties': {}, 'title': 'SSB (AC) 10', 'source_file_path': None, 'datetime_modified': {'local_datetime': '2025-04-10T08:37:13.907129', 'tz': '+0200', 'dst': '+60', 'timezone': 'Europe/Vienna'}, 'datetime_original': {'local_datetime': '2025-04-10T08:37:13.907129', 'tz': '+0200', 'dst': '+60', 'timezone': 'Europe/Vienna'}, 'uuid': '04982611-0b3c-4a7f-b873-fcc117e72cbd'}
# Image shape at index 22: (512, 512)
# Metadata at index 22: {'version': 1, 'reader_version': 1, 'large_format': False, 'spatial_calibrations': [{'offset': -2.0, 'scale': 0.0078125, 'units': 'nm'}, {'offset': -2.0, 'scale': 0.0078125, 'units': 'nm'}], 'intensity_calibration': {'offset': 0.0, 'scale': 1.0, 'units': 'counts'}, 'collection_dimension_count': 0, 'datum_dimension_count': 2, 'metadata': {}, 'properties': {}, 'title': 'SSB (AC) 7', 'source_file_path': None, 'datetime_modified': {'local_datetime': '2025-04-10T07:45:44.385464', 'tz': '+0200', 'dst': '+60', 'timezone': 'Europe/Vienna'}, 'datetime_original': {'local_datetime': '2025-04-10T07:45:44.385464', 'tz': '+0200', 'dst': '+60', 'timezone': 'Europe/Vienna'}, 'uuid': '6f247df1-7b16-43dc-a673-572625ec8667'}
# Image title at index 22: ['SSB (AC) 7']
# {'version': 1, 'reader_version': 1, 'large_format': False, 'spatial_calibrations': [{'offset': -2.0, 'scale': 0.0078125, 'units': 'nm'}, {'offset': -2.0, 'scale': 0.0078125, 'units': 'nm'}], 'intensity_calibration': {'offset': 0.0, 'scale': 1.0, 'units': 'counts'}, 'collection_dimension_count': 0, 'datum_dimension_count': 2, 'metadata': {}, 'properties': {}, 'title': 'SSB (AC) 7', 'source_file_path': None, 'datetime_modified': {'local_datetime': '2025-04-10T07:45:44.385464', 'tz': '+0200', 'dst': '+60', 'timezone': 'Europe/Vienna'}, 'datetime_original': {'local_datetime': '2025-04-10T07:45:44.385464', 'tz': '+0200', 'dst': '+60', 'timezone': 'Europe/Vienna'}, 'uuid': '6f247df1-7b16-43dc-a673-572625ec8667'}

# %%
#Reading EELS data example
img = EELSLazyLoader(filepath_eels)
data_image = img.image
data_image_metadata = img.image_metadata
data_spectrum = img.spectrum
data_spectrum_metadata = img.spectrum_metadata
data_filenames = img.get_original_filenames(0)
print(f"Number of pairs: {len(data_image)}")
print(f"First image shape: {data_image[2].shape}")
print(f"First spectrum shape: {len(data_spectrum[0])}")
print(f"First image metadata: {data_image_metadata[0]}")
print(f"First spectrum metadata: {data_spectrum_metadata[0]}")
print(f"Original filenames for first pair: {data_filenames}")
# Out:
# Number of pairs: 3
# First image shape: (512, 512)
# First spectrum shape: 512
# First image metadata: {'version': 1, 'reader_version': 1, 'large_format': False, 'spatial_calibrations': [{'offset': -1.0, 'scale': 0.00390625, 'units': 'nm'}, {'offset': -1.0, 'scale': 0.00390625, 'units': 'nm'}], 'intensity_calibration': {'offset': 0.0, 'scale': 1.0, 'units': ''}, 'collection_dimension_count': 0, 'datum_dimension_count': 2, 'metadata': {'instrument': {'high_tension': 60000.0, 'defocus': 3.43777599800433e-10, 'ImageScanned': {'C1 ConstW': 0.563546000000003, 'EHT': 60000.0, 'PMTBF_gain': 6400.0, 'PMTDF_gain': 80000.0, 'S_EELS': 1.0, 'StageOutA': -1.17060138569237e-08, 'StageOutB': 1.03801286139456e-08, 'StageOutX': -0.000901344277643758, 'StageOutY': 0.000293965330421273, 'StageOutZ': 0.000408483387018692, 'BP2_^VGVOACurrent': 6.031116e-10, 'probe_ha': 0.035, 'C10': 3.43777599800433e-10, 'C12.a': -3.07088196191574e-09, 'C12.b': 5.70944515318526e-10, 'C21.a': 4.02929386449591e-08, 'C21.b': -9.40980715101662e-08, 'C23.a': 1.32545670706938e-08, 'C23.b': 4.78624130207036e-08, 'C30': -1.76890014916472e-06, 'C32.a': 7.03037093263516e-06, 'C32.b': -4.98744679630134e-06, 'C34.a': -1.17268959226307e-06, 'C34.b': 5.92021125875038e-07, 'C41.a': -0.000179665994826146, 'C41.b': 0.000120506589942353, 'C43.a': 2.19055905905777e-05, 'C43.b': -0.000102871187410997, 'C45.a': -3.51654942645782e-05, 'C45.b': -1.53210324117638e-05, 'C50': -0.000653935892940758, 'C52.a': -0.00335627278050581, 'C52.b': 0.00194452974383046, 'C54.a': -0.00116205198674251, 'C54.b': -9.37873861637805e-05, 'C56.a': -9.85071513168029e-05, 'C56.b': 0.000145232826503806}}, 'scan': {'hardware_source_id': 'superscan', 'hardware_source_name': 'SuperScan', 'scan_id': 'ac09d0da-6fe0-48e0-b8d9-4afbd35852ed', 'center_x_nm': 0.0, 'center_y_nm': 0.0, 'fov_nm': 2.0, 'rotation': 0.0, 'rotation_deg': 0.0, 'scan_context_size': [512, 512], 'scan_size': [512, 512], 'scan_device_parameters': {'pixel_size': [512, 512], 'center_nm': [0.0, 0.0], 'pixel_time_us': 4.0, 'fov_nm': 2.0, 'rotation_rad': 0.0, 'ac_line_sync': False, 'ac_frame_sync': False, 'external_clock_mode': 0, 'external_clock_wait_time_ms': 0, 'external_scan_mode': 0, 'external_scan_ratio': 0.0, 'subscan_rotation': 0.0}, 'scan_device_properties': {'ac_line_sync': 2.0, 'calibration_style': 'space', 'center_x_nm': 0.0, 'center_y_nm': 0.0, 'flyback_pixels': 55.0, 'flyback_time_us': 220.0, 'fov_nm': 1.99999994343614, 'line_time_us': 2268.0, 'pixel_time_us': 4.0, 'pixels_x': 512.0, 'pixels_y': 512.0, 'requested_pixel_time_us': 3.99999998990097, 'rotation_deg': 0.0, 'rotation_rad': 0.0, 'mag_boards': {'MagBoard 0 DAC 0': 0.0, 'MagBoard 0 DAC 1': 0.0, 'MagBoard 0 DAC 10': 10115.0, 'MagBoard 0 DAC 11': 7353.0, 'MagBoard 0 DAC 2': 0.0, 'MagBoard 0 DAC 3': 0.0, 'MagBoard 0 DAC 4': 10735.0, 'MagBoard 0 DAC 5': 58420.0, 'MagBoard 0 DAC 6': 11776.0, 'MagBoard 0 DAC 7': 59325.0, 'MagBoard 0 DAC 8': 53520.0, 'MagBoard 0 DAC 9': 59903.0, 'MagBoard 0 Relay': 0.0, 'MagBoard 1 DAC 0': 0.0, 'MagBoard 1 DAC 1': 0.0, 'MagBoard 1 DAC 10': 45659.0, 'MagBoard 1 DAC 11': 10928.0, 'MagBoard 1 DAC 2': 0.0, 'MagBoard 1 DAC 3': 0.0, 'MagBoard 1 DAC 4': 47873.0, 'MagBoard 1 DAC 5': 9197.0, 'MagBoard 1 DAC 6': 17182.0, 'MagBoard 1 DAC 7': 54252.0, 'MagBoard 1 DAC 8': 50180.0, 'MagBoard 1 DAC 9': 10080.0, 'MagBoard 1 Relay': 0.0}}, 'valid_rows': 512}, 'hardware_source': {'hardware_source_id': 'superscan', 'hardware_source_name': 'SuperScan', 'exposure': 1.048576, 'frame_index': 3, 'channel_id': 'a', 'channel_name': 'HAADF', 'pixel_time_us': 4.0, 'line_time_us': 2268.0, 'valid_rows': 512, 'channel_index': 0, 'reference_key': 'superscan_a', 'point_spectrum_no': 18119}}, 'properties': {'hardware_source_id': 'superscan', 'hardware_source_name': 'SuperScan', 'exposure': 1.048576, 'frame_index': 3, 'channel_id': 'a', 'channel_name': 'HAADF', 'pixel_time_us': 4.0, 'line_time_us': 2268.0, 'valid_rows': 512, 'channel_index': 0, 'reference_key': 'superscan_a', 'point_spectrum_no': 18119}, 'title': 'HAADF for point spectrum #18119', 'source_file_path': No ...
# First spectrum metadata: {'version': 1, 'reader_version': 1, 'large_format': False, 'spatial_calibrations': [{'offset': 35.296, 'scale': 0.159, 'units': 'eV'}], 'intensity_calibration': {'offset': 0.0, 'scale': 1.0, 'units': 'counts'}, 'collection_dimension_count': 0, 'datum_dimension_count': 1, 'metadata': {'hardware_source': {'frame_number': 18117, 'frame_parameters': {'exposure_ms': 16.00000075995922, 'temperature_target': -60, 'fan_on': False, 'trigger_mode': 'internal', 'shutter_mode': 'permanently open', 'read_mode': 'single track', 'flip_l_r': True, 'use_dark_images': True, 'use_gain_images': True, 'vertical_shift_speed': 0, 'vertical_shift_amplitude': 3, 'horizontal_shift_speed': 0, 'auto_adjust_exposure': False, 'readout_area': [150, 1, 402, 512], 'crop': True, 'acquire_dark_before_sequence': False, 'em_advanced': 1, 'energy_calibration': {'energy_offset': 0, 'energy_shift': 76.0, 'energy_region_position': 0.5, 'dispersion': 0.159}, 'auto_unblank_on_acquisition': True, 'auto_save_snapshot': True, 'gain': 80, 'preamp_gain': 0, 'frame_transfer': False, 'binning': 1, 'kinetic_ms': 2029.4198989868164, 'accumulate_ms': 16.920000314712524, 'kinetic_length': 4224, 'accumulate_length': 120, 'software_fvb': False, 'mode': 'accumulate'}, 'probe_position': {'x': 0.6542624958780439, 'y': 0.5535067529325616}, 'dark_image': {'frame_parameters': {'exposure_ms': 2000.0, 'temperature_target': -65, 'fan_on': False, 'trigger_mode': 'software', 'shutter_mode': 'permanently closed', 'read_mode': 'image', 'flip_l_r': False, 'use_dark_images': False, 'use_gain_images': False, 'vertical_shift_speed': 0, 'vertical_shift_amplitude': 3, 'horizontal_shift_speed': 0, 'auto_adjust_exposure': False, 'readout_area': [1, 1, 512, 512], 'crop': False, 'acquire_dark_before_sequence': False, 'em_advanced': 1, 'energy_calibration': {'energy_offset': 0.0, 'energy_shift': 0.0, 'energy_region_position': 0.5, 'dispersion': 0.5}, 'auto_unblank_on_acquisition': True, 'auto_save_snapshot': True, 'gain': 100, 'preamp_gain': 0, 'frame_transfer': True, 'binning': [1, 1], 'kinetic_ms': 2018.251895904541, 'accumulate_ms': 2018.251895904541, 'kinetic_length': 1, 'accumulate_length': 1, 'software_fvb': False, 'mode': 'continuous'}, 'method': 'scalable', 'type': 'dark'}, 'counts_per_electron': 1, 'hardware_source_id': 'andor_eels_camera', 'hardware_source_name': 'Andor EELS', 'exposure': 0.01600000075995922, 'binning': 1, 'signal_type': 'eels', 'valid_rows': 512, 'frame_index': 36, 'integration_count': 1, 'channel_index': 0, 'reference_key': 'andor_eels_camera'}, 'instrument': {'high_tension': 60000.0, 'defocus': 3.43777599800433e-10}}, 'properties': {'frame_number': 18117, 'frame_parameters': {'exposure_ms': 16.00000075995922, 'temperature_target': -60, 'fan_on': False, 'trigger_mode': 'internal', 'shutter_mode': 'permanently open', 'read_mode': 'single track', 'flip_l_r': True, 'use_dark_images': True, 'use_gain_images': True, 'vertical_shift_speed': 0, 'vertical_shift_amplitude': 3, 'horizontal_shift_speed': 0, 'auto_adjust_exposure': False, 'readout_area': [150, 1, 402, 512], 'crop': True, 'acquire_dark_before_sequence': False, 'em_advanced': 1, 'energy_calibration': {'energy_offset': 0, 'energy_shift': 76.0, 'energy_region_position': 0.5, 'dispersion': 0.159}, 'auto_unblank_on_acquisition': True, 'auto_save_snapshot': True, 'gain': 80, 'preamp_gain': 0, 'frame_transfer': False, 'binning': 1, 'kinetic_ms': 2029.4198989868164, 'accumulate_ms': 16.920000314712524, 'kinetic_length': 4224, 'accumulate_length': 120, 'software_fvb': False, 'mode': 'accumulate'}, 'probe_position': {'x': 0.6542624958780439, 'y': 0.5535067529325616}, 'dark_image': {'frame_parameters': {'exposure_ms': 2000.0, 'temperature_target': -65, 'fan_on': False, 'trigger_mode': 'software', 'shutter_mode': 'permanently closed', 'read_mode': 'image', 'flip_l_r': False, 'use_dark_images': False, 'use_gain_images': False, 'vertical_shift_speed': 0, 'vertical_shift_amplitude': 3, 'horizontal_shift_speed': 0 ...
# Original filenames for first pair: {'point_spectrum': 'Point spectrum #18119.ndata1', 'image': 'HAADF for point spectrum #18119.ndata1'}
